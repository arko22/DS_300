# %% [markdown]
# <span style="font-size:2em;"> ****Data Science 300 Final Project**** </span>
#
# <span style="font-size:1em;">**Anonymizing AirBnb (New York) 2019 listings database**</span>

# %% [markdown]
# <span style="font-size:1.5em;">First, lets Import the following libraries:</span>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <span style="font-size:1.5em;">Now we will use the pandas library function **'.read_csv'** to import the csv file to pandas as a DataFrame to this notebook:</span>

# %%
# You can change the path to where the file is on your computer by editing the dataset_path defintion below:
dataset_path = "/Users/arko/Desktop/AB_NYC_2019.csv"

air_db = pd.read_csv(dataset_path)

# %% [markdown]
# <span style="font-size:1.5em;">The first step of **k-anonymization** is to the remove the **Explicit identifiers** from the original database. Since I already took a look at the database I know the Explicit Identifiers to be:
#
# * <span style="font-size:1.5em;">id</span>
# * <span style="font-size:1.5em;">name</span>
# * <span style="font-size:1.5em;">host_name</span>
# * <span style="font-size:1.5em;">host_id</span><br>
#
# <span style="font-size:1.5em;">We **remove these fields from the database** and print the first 5 rows of the new table.</span>

# %%
#drop all the excplicit identifiers from the table
air_db = air_db.drop("id", axis=1)
air_db = air_db.drop("name", axis=1)
air_db = air_db.drop("host_name", axis=1)
air_db = air_db.drop("host_id", axis=1)

#Print first 5 rows to check new data
air_db.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# <span style="font-size:1.5em;">We selected *latitude*, *longitudate* and *price* as **Quasi Identifiers** for this dataset, and hence must generalize these values. For **latitude** and **longitude** I found it very hard to generalize without removing most of it's utility, so I **suppressed both** of them.</span>

# %%
latitude = air_db['latitude']
air_db['latitude'] = air_db['latitude'].mask(latitude>40,"40.****")

# %%
longitude = air_db['longitude']
air_db['longitude'] = air_db['longitude'].mask(longitude < -73,"-73.****")

# %%
air_db['longitude'] = air_db['longitude'].mask(longitude<-74,"-74.****")

# %% [markdown]
# <span style="font-size:1.5em;">Now we generalize price by using ranged labels for the price, and creating a new field called **price_range**. It will be appended **price_range** to the last field of the table.</span>

# %%
labels = ["{0} - {1}".format(i, i + 49) for i in range(0, 10000, 50)]

#print(len(labels)) -> output -> 200 -> hence we can created 200 labels

# New column called price_range

air_db["price_range"] = pd.cut(air_db.price, range(0, 10001, 50), right=False, labels=labels)

#Print first 10 rows to check new data

air_db.head()
# Out:
#   neighbourhood_group neighbourhood latitude longitude        room_type  \
# 0            Brooklyn    Kensington  40.****  -73.****     Private room
# 1           Manhattan       Midtown  40.****  -73.****  Entire home/apt
# 2           Manhattan        Harlem  40.****  -73.****     Private room
# 3            Brooklyn  Clinton Hill  40.****  -73.****  Entire home/apt
# 4           Manhattan   East Harlem  40.****  -73.****  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365 price_range
# 0                               6               365   100 - 149
# 1                               2               355   200 - 249
# 2                               1               365   150 - 199
# 3                               1               194     50 - 99
# 4                               1                 0     50 - 99

# %% [markdown]
# <span style="font-size:1.5em;">Now we will change the position of **price_range** in the table to make it easier to observe. We will not drop the original **price** column just yet, as we need it in the last part of this code.</span>

# %%
price_range =air_db["price_range"]

air_db = air_db.drop("price_range", axis=1)

#air_db = air_db.drop("price", axis=1)

# %%
air_db.insert(2, "price_range",price_range)
air_db.head()
# Out:
#   neighbourhood_group neighbourhood price_range latitude longitude  \
# 0            Brooklyn    Kensington   100 - 149  40.****  -73.****
# 1           Manhattan       Midtown   200 - 249  40.****  -73.****
# 2           Manhattan        Harlem   150 - 199  40.****  -73.****
# 3            Brooklyn  Clinton Hill     50 - 99  40.****  -73.****
# 4           Manhattan   East Harlem     50 - 99  40.****  -73.****
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# <span style="font-size:1.5em;">Now we are going to group the dataset with the pandas function "**.groupby**" using **price_range** as the parameter. It is important to note that the "**.groupby**" function will return a pandas object, and we need to print the output to see if the function worked. I did this using a loop below. </span>

# %%
g = air_db.groupby('price_range')
g

# %%
for price_g, price_g_air_db in g:
    print(price_g)
    print(price_g_air_db)
# Out:
# 0 - 49
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 28              Manhattan              Inwood      0 - 49  40.****  -73.****
# 36               Brooklyn  Bedford-Stuyvesant      0 - 49  40.****  -73.****
# 39              Manhattan     Lower East Side      0 - 49  40.****  -73.****
# 58               Brooklyn          Greenpoint      0 - 49  40.****  -73.****
# 149              Brooklyn         Fort Greene      0 - 49  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 48871           Manhattan              Harlem      0 - 49  40.****  -73.****
# 48877            Brooklyn            Bushwick      0 - 49  40.****  -73.****
# 48878              Queens            Elmhurst      0 - 49  40.****  -73.****
# 48882            Brooklyn            Bushwick      0 - 49  40.****  -73.****
# 48891            Brooklyn            Bushwick      0 - 49  40.****  -73.****
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 28     Private room     44               3                108  2019-06-15
# 36     Private room     35              60                  0         NaN
# 39      Shared room     40               1                214  2019-07-05
# 58     Private room     49               4                138  2019-06-04
# 149    Private room     44               8                 27  2019-06-29
# ...             ...    ...             ...                ...         ...
# 48871  Private room     35              29                  0         NaN
# 48877  Private room     42               7                  0         NaN
# 48878  Private room     45               1                  0         NaN
# 48882  Private room     40              20                  0         NaN
# 48891  Private room     40               4                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 28                  1.11                               3               311
# 36                   NaN                               1               365
# 39                  1.81                               4               188
# 58                  1.19                               3               320
# 149                 1.05                               5               280
# ...                  ...                             ...               ...
# 48871                NaN                               2                31
# 48877                NaN                               1                16
# 48878                NaN                               5               172
# 48882                NaN                               1                31
# 48891                NaN                               2                36
#
# [5027 rows x 13 columns]
# 50 - 99
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 3                Brooklyn        Clinton Hill     50 - 99  40.****  -73.****
# 4               Manhattan         East Harlem     50 - 99  40.****  -73.****
# 6                Brooklyn  Bedford-Stuyvesant     50 - 99  40.****  -73.****
# 7               Manhattan      Hell's Kitchen     50 - 99  40.****  -73.****
# 8               Manhattan     Upper West Side     50 - 99  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 48885           Manhattan         East Harlem     50 - 99  40.****  -73.****
# 48889              Queens             Jamaica     50 - 99  40.****  -73.****
# 48890            Brooklyn  Bedford-Stuyvesant     50 - 99  40.****  -73.****
# 48893           Manhattan      Hell's Kitchen     50 - 99  40.****  -73.****
# 48894           Manhattan      Hell's Kitchen     50 - 99  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 6         Private room     60              45                 49  2017-10-05
# 7         Private room     79               2                430  2019-06-24
# 8         Private room     79               2                118  2017-07-21
# ...                ...    ...             ...                ...         ...
# 48885     Private room     75               2                  0         NaN
# 48889     Private room     65               1                  0         NaN
# 48890     Private room     70               2                  0         NaN
# 48893      Shared room     55               1                  0         NaN
# 48894     Private room     90               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 6                   0.40                               1                 0
# 7                   3.47                               1               220
# 8                   0.99                               1                 0
# ...                  ...                             ...               ...
# 48885                NaN                               2               353
# 48889                NaN                               2               163
# 48890                NaN                               2                 9
# 48893                NaN                               6                 2
# 48894                NaN                               1                23
#
# [16850 rows x 13 columns]
# 100 - 149
#       neighbourhood_group    neighbourhood price_range latitude longitude  \
# 0                Brooklyn       Kensington   100 - 149  40.****  -73.****
# 10              Manhattan  Upper West Side   100 - 149  40.****  -73.****
# 14              Manhattan     West Village   100 - 149  40.****  -74.****
# 15               Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 17              Manhattan          Chelsea   100 - 149  40.****  -73.****
# ...                   ...              ...         ...      ...       ...
# 48875           Manhattan      East Harlem   100 - 149  40.****  -73.****
# 48879            Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 48880            Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 48888           Manhattan   Hell's Kitchen   100 - 149  40.****  -73.****
# 48892           Manhattan           Harlem   100 - 149  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 10     Entire home/apt    135               5                 53  2019-06-22
# 14     Entire home/apt    120              90                 27  2018-10-31
# 15     Entire home/apt    140               2                148  2019-06-29
# 17        Private room    140               1                260  2019-07-01
# ...                ...    ...             ...                ...         ...
# 48875     Private room    140               1                  0         NaN
# 48879  Entire home/apt    120              20                  0         NaN
# 48880  Entire home/apt    120               1                  0         NaN
# 48888     Private room    125               4                  0         NaN
# 48892  Entire home/apt    115              10                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 10                  0.43                               1                 6
# 14                  0.22                               1                 0
# 15                  1.20                               1                46
# 17                  2.12                               1                12
# ...                  ...                             ...               ...
# 48875                NaN                               1               180
# 48879                NaN                               1                22
# 48880                NaN                               3               365
# 48888                NaN                               1                31
# 48892                NaN                               1                27
#
# [10033 rows x 13 columns]
# 150 - 199
#       neighbourhood_group   neighbourhood price_range latitude longitude  \
# 2               Manhattan          Harlem   150 - 199  40.****  -73.****
# 9               Manhattan       Chinatown   150 - 199  40.****  -73.****
# 19              Manhattan     East Harlem   150 - 199  40.****  -73.****
# 27              Manhattan  Hell's Kitchen   150 - 199  40.****  -73.****
# 29              Manhattan    East Village   150 - 199  40.****  -73.****
# ...                   ...             ...         ...      ...       ...
# 48850           Manhattan    East Village   150 - 199  40.****  -73.****
# 48854            Brooklyn      Greenpoint   150 - 199  40.****  -73.****
# 48873            Brooklyn       Flatlands   150 - 199  40.****  -73.****
# 48884            Brooklyn    Williamsburg   150 - 199  40.****  -73.****
# 48887            Brooklyn    Williamsburg   150 - 199  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 2         Private room    150               3                  0         NaN
# 9      Entire home/apt    150               1                160  2019-06-09
# 19     Entire home/apt    190               7                  0         NaN
# 27     Entire home/apt    150              10                 58  2017-08-13
# 29     Entire home/apt    180              14                 29  2019-04-19
# ...                ...    ...             ...                ...         ...
# 48850  Entire home/apt    159               1                  0         NaN
# 48854     Private room    150               4                  0         NaN
# 48873  Entire home/apt    170               1                  0         NaN
# 48884     Private room    190               7                  0         NaN
# 48887  Entire home/apt    170               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 2                    NaN                               1               365
# 9                   1.33                               4               188
# 19                   NaN                               2               249
# 27                  0.49                               1                75
# 29                  0.24                               1                67
# ...                  ...                             ...               ...
# 48850                NaN                               1               166
# 48854                NaN                               1               267
# 48873                NaN                               2               363
# 48884                NaN                               1               341
# 48887                NaN                               3               365
#
# [7200 rows x 13 columns]
# 200 - 249
#       neighbourhood_group neighbourhood price_range latitude longitude  \
# 1               Manhattan       Midtown   200 - 249  40.****  -73.****
# 5               Manhattan   Murray Hill   200 - 249  40.****  -73.****
# 16               Brooklyn   Fort Greene   200 - 249  40.****  -73.****
# 52               Brooklyn  Williamsburg   200 - 249  40.****  -73.****
# 54              Manhattan      Kips Bay   200 - 249  40.****  -73.****
# ...                   ...           ...         ...      ...       ...
# 48831            Brooklyn  Williamsburg   200 - 249  40.****  -73.****
# 48841              Queens       Astoria   200 - 249  40.****  -73.****
# 48844           Manhattan  West Village   200 - 249  40.****  -74.****
# 48853           Manhattan  West Village   200 - 249  40.****  -74.****
# 48886           Manhattan       Midtown   200 - 249  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 1      Entire home/apt    225               1                 45  2019-05-21
# 5      Entire home/apt    200               3                 74  2019-06-22
# 16     Entire home/apt    215               2                198  2019-06-28
# 52     Entire home/apt    228               3                 82  2019-05-17
# 54     Entire home/apt    200               7                 19  2019-03-25
# ...                ...    ...             ...                ...         ...
# 48831  Entire home/apt    225               1                  0         NaN
# 48841  Entire home/apt    210               7                  0         NaN
# 48844  Entire home/apt    205               1                  0         NaN
# 48853     Private room    202               2                  0         NaN
# 48886  Entire home/apt    200               6                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1                   0.38                               2               355
# 5                   0.59                               1               129
# 16                  1.72                               1               321
# 52                  0.70                               1               140
# 54                  0.22                               1               257
# ...                  ...                             ...               ...
# 48831                NaN                               1                84
# 48841                NaN                               1                12
# 48844                NaN                               1               365
# 48853                NaN                               1                84
# 48886                NaN                               1               176
#
# [3559 rows x 13 columns]
# 250 - 299
#       neighbourhood_group     neighbourhood price_range latitude longitude  \
# 20               Brooklyn      Williamsburg   250 - 299  40.****  -73.****
# 62              Manhattan   Upper East Side   250 - 299  40.****  -73.****
# 68               Brooklyn      Williamsburg   250 - 299  40.****  -73.****
# 82              Manhattan   Lower East Side   250 - 299  40.****  -73.****
# 93               Brooklyn  Prospect Heights   250 - 299  40.****  -73.****
# ...                   ...               ...         ...      ...       ...
# 48751              Queens      Breezy Point   250 - 299  40.****  -73.****
# 48770           Manhattan       Murray Hill   250 - 299  40.****  -73.****
# 48784           Manhattan   Upper East Side   250 - 299  40.****  -73.****
# 48785           Manhattan    Hell's Kitchen   250 - 299  40.****  -73.****
# 48872           Manhattan    Hell's Kitchen   250 - 299  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 20     Entire home/apt    299               3                  9  2011-12-28
# 62     Entire home/apt    250               2                 66  2019-03-30
# 68     Entire home/apt    275               1                148  2019-06-23
# 82     Entire home/apt    285               5                 70  2019-06-30
# 93     Entire home/apt    250               7                 21  2019-05-21
# ...                ...    ...             ...                ...         ...
# 48751     Private room    250               1                  0         NaN
# 48770  Entire home/apt    250               5                  0         NaN
# 48784  Entire home/apt    250              45                  0         NaN
# 48785      Shared room    260               1                  0         NaN
# 48872  Entire home/apt    260               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 20                  0.07                               1                 0
# 62                  0.57                               2               231
# 68                  1.40                               1               362
# 82                  0.62                               1               328
# 93                  0.30                               1               158
# ...                  ...                             ...               ...
# 48751                NaN                               1                82
# 48770                NaN                               1               233
# 48784                NaN                               1                83
# 48785                NaN                               2               168
# 48872                NaN                               1                 9
#
# [2308 rows x 13 columns]
# 300 - 349
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 116              Brooklyn        Williamsburg   300 - 349  40.****  -73.****
# 223             Manhattan   Flatiron District   300 - 349  40.****  -73.****
# 327              Brooklyn          Greenpoint   300 - 349  40.****  -73.****
# 328              Brooklyn          Greenpoint   300 - 349  40.****  -73.****
# 440             Manhattan              Harlem   300 - 349  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 48611           Manhattan      Hell's Kitchen   300 - 349  40.****  -73.****
# 48635           Manhattan             Tribeca   300 - 349  40.****  -74.****
# 48700           Manhattan             Midtown   300 - 349  40.****  -73.****
# 48723           Manhattan              Nolita   300 - 349  40.****  -73.****
# 48856            Brooklyn  Bedford-Stuyvesant   300 - 349  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 116    Entire home/apt    325               3                324  2019-06-23
# 223    Entire home/apt    305               2                108  2019-06-30
# 327       Private room    349               3                  8  2016-03-27
# 328       Private room    349               3                  7  2019-05-24
# 440    Entire home/apt    300               2                203  2019-07-06
# ...                ...    ...             ...                ...         ...
# 48611  Entire home/apt    300               5                  0         NaN
# 48635  Entire home/apt    349               3                  0         NaN
# 48700  Entire home/apt    325               5                  0         NaN
# 48723  Entire home/apt    316              30                  0         NaN
# 48856  Entire home/apt    345               4                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 116                 3.01                               1               107
# 223                 1.09                               1               201
# 327                 0.09                              28                60
# 328                 0.07                              28                60
# 440                 2.14                               3               258
# ...                  ...                             ...               ...
# 48611                NaN                               1                34
# 48635                NaN                               1                11
# 48700                NaN                               1               298
# 48723                NaN                             232               325
# 48856                NaN                               3               354
#
# [1081 rows x 13 columns]
# 350 - 399
#       neighbourhood_group     neighbourhood price_range latitude longitude  \
# 61              Manhattan           Chelsea   350 - 399  40.****  -73.****
# 114             Manhattan      East Village   350 - 399  40.****  -73.****
# 181                Queens         Ridgewood   350 - 399  40.****  -73.****
# 263             Manhattan      East Village   350 - 399  40.****  -73.****
# 324              Brooklyn      Clinton Hill   350 - 399  40.****  -73.****
# ...                   ...               ...         ...      ...       ...
# 48747              Queens  Long Island City   350 - 399  40.****  -73.****
# 48748           Manhattan           Midtown   350 - 399  40.****  -73.****
# 48755           Manhattan           Midtown   350 - 399  40.****  -73.****
# 48758              Queens  Long Island City   350 - 399  40.****  -73.****
# 48842           Manhattan           Chelsea   350 - 399  40.****  -74.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 61     Entire home/apt    375             180                  5  2018-11-03
# 114    Entire home/apt    350               2                  7  2017-08-09
# 181    Entire home/apt    350               8                 10  2019-05-12
# 263    Entire home/apt    390               5                143  2019-06-19
# 324    Entire home/apt    350               6                 14  2019-04-20
# ...                ...    ...             ...                ...         ...
# 48747  Entire home/apt    375               2                  0         NaN
# 48748  Entire home/apt    369               4                  0         NaN
# 48755     Private room    380               3                  0         NaN
# 48758  Entire home/apt    350               2                  0         NaN
# 48842  Entire home/apt    350               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 61                  0.12                               1               180
# 114                 0.06                               4               298
# 181                 0.11                               5               365
# 263                 1.38                               2               316
# 324                 0.30                               1               156
# ...                  ...                             ...               ...
# 48747                NaN                               1               364
# 48748                NaN                               3                 4
# 48755                NaN                               1                 3
# 48758                NaN                               1               364
# 48842                NaN                               1                 9
#
# [849 rows x 13 columns]
# 400 - 449
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 121              Brooklyn         South Slope   400 - 449  40.****  -73.****
# 494             Manhattan            Gramercy   400 - 449  40.****  -73.****
# 501             Manhattan             Chelsea   400 - 449  40.****  -73.****
# 637              Brooklyn        Clinton Hill   400 - 449  40.****  -73.****
# 661             Manhattan              Harlem   400 - 449  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 48565           Manhattan             Chelsea   400 - 449  40.****  -73.****
# 48595           Manhattan     Upper East Side   400 - 449  40.****  -73.****
# 48616           Manhattan    Theater District   400 - 449  40.****  -73.****
# 48626           Manhattan  Financial District   400 - 449  40.****  -74.****
# 48683            Brooklyn        Clinton Hill   400 - 449  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 121    Entire home/apt    400               2                 16  2018-12-30
# 494    Entire home/apt    400               2                105  2019-06-23
# 501    Entire home/apt    429              10                 18  2019-06-24
# 637       Private room    438               1                 43  2019-04-14
# 661    Entire home/apt    400               5                  0         NaN
# ...                ...    ...             ...                ...         ...
# 48565  Entire home/apt    421              30                  0         NaN
# 48595  Entire home/apt    400               5                  0         NaN
# 48616  Entire home/apt    400               2                  0         NaN
# 48626  Entire home/apt    430               3                  0         NaN
# 48683  Entire home/apt    400               5                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 121                 0.24                               2               216
# 494                 1.13                               1               304
# 501                 0.90                               1                 0
# 637                 0.46                              11               363
# 661                  NaN                               2               365
# ...                  ...                             ...               ...
# 48565                NaN                             232               292
# 48595                NaN                               2               363
# 48616                NaN                               1                 3
# 48626                NaN                               1                42
# 48683                NaN                               1                13
#
# [392 rows x 13 columns]
# 450 - 499
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 158              Brooklyn         Boerum Hill   450 - 499  40.****  -73.****
# 418              Brooklyn          Park Slope   450 - 499  40.****  -73.****
# 430              Brooklyn        Williamsburg   450 - 499  40.****  -73.****
# 460              Brooklyn        Williamsburg   450 - 499  40.****  -73.****
# 689             Manhattan              Nolita   450 - 499  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 48533       Staten Island           Stapleton   450 - 499  40.****  -74.****
# 48561           Manhattan                SoHo   450 - 499  40.****  -73.****
# 48680           Manhattan             Chelsea   450 - 499  40.****  -74.****
# 48744            Brooklyn        Williamsburg   450 - 499  40.****  -73.****
# 48833           Manhattan  Financial District   450 - 499  40.****  -74.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 158    Entire home/apt    475               3                 23  2018-12-31
# 418    Entire home/apt    495               1                 35  2018-01-13
# 430    Entire home/apt    451               2                 72  2019-05-11
# 460    Entire home/apt    450               5                 37  2018-12-27
# 689    Entire home/apt    495               7                 25  2019-06-30
# ...                ...    ...             ...                ...         ...
# 48533  Entire home/apt    450               5                  0         NaN
# 48561  Entire home/apt    466              30                  0         NaN
# 48680  Entire home/apt    450               5                  0         NaN
# 48744  Entire home/apt    499              30                  0         NaN
# 48833  Entire home/apt    475               2                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 158                 0.27                               1               230
# 418                 0.41                               1               355
# 430                 0.86                               1               331
# 460                 0.79                               1                15
# 689                 0.27                               2               338
# ...                  ...                             ...               ...
# 48533                NaN                               1                88
# 48561                NaN                             232               354
# 48680                NaN                               1               167
# 48744                NaN                               1               365
# 48833                NaN                               1                64
#
# [361 rows x 13 columns]
# 500 - 549
#       neighbourhood_group    neighbourhood price_range latitude longitude  \
# 103             Manhattan     West Village   500 - 549  40.****  -74.****
# 233             Manhattan             SoHo   500 - 549  40.****  -74.****
# 242             Manhattan          Chelsea   500 - 549  40.****  -74.****
# 304             Manhattan     East Village   500 - 549  40.****  -73.****
# 467              Brooklyn  Carroll Gardens   500 - 549  40.****  -73.****
# ...                   ...              ...         ...      ...       ...
# 47653           Manhattan   Hell's Kitchen   500 - 549  40.****  -73.****
# 47737            Brooklyn     Williamsburg   500 - 549  40.****  -73.****
# 47775              Queens          Astoria   500 - 549  40.****  -73.****
# 48227           Manhattan          Tribeca   500 - 549  40.****  -74.****
# 48509           Manhattan  Upper West Side   500 - 549  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 103    Entire home/apt    500               4                 46  2019-05-18
# 233    Entire home/apt    500               4                 94  2019-06-23
# 242    Entire home/apt    500               2                 35  2017-07-27
# 304    Entire home/apt    500               2                 48  2019-06-16
# 467    Entire home/apt    500               7                  7  2018-08-29
# ...                ...    ...             ...                ...         ...
# 47653  Entire home/apt    500               1                  4  2019-07-06
# 47737  Entire home/apt    500               4                  0         NaN
# 47775  Entire home/apt    500               2                  0         NaN
# 48227     Private room    500               5                  0         NaN
# 48509  Entire home/apt    520              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 103                 0.55                               2               243
# 233                 0.99                               1               329
# 242                 0.34                               1               348
# 304                 0.48                               4               297
# 467                 0.07                               1                 0
# ...                  ...                             ...               ...
# 47653               4.00                               2                 2
# 47737                NaN                               1               358
# 47775                NaN                               1               157
# 48227                NaN                               1               252
# 48509                NaN                               1               310
#
# [249 rows x 13 columns]
# 550 - 599
#       neighbourhood_group     neighbourhood price_range latitude longitude  \
# 299             Manhattan      Little Italy   550 - 599  40.****  -73.****
# 365              Brooklyn        Greenpoint   550 - 599  40.****  -73.****
# 684              Brooklyn        Greenpoint   550 - 599  40.****  -73.****
# 1451            Manhattan              SoHo   550 - 599  40.****  -73.****
# 1527             Brooklyn        Park Slope   550 - 599  40.****  -73.****
# ...                   ...               ...         ...      ...       ...
# 48119           Manhattan   Upper West Side   550 - 599  40.****  -73.****
# 48170           Manhattan           Chelsea   550 - 599  40.****  -74.****
# 48184            Brooklyn      Williamsburg   550 - 599  40.****  -73.****
# 48232           Manhattan    Hell's Kitchen   550 - 599  40.****  -73.****
# 48740            Brooklyn  Brooklyn Heights   550 - 599  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 299    Entire home/apt    575               2                191  2019-06-20
# 365       Private room    599               3                  9  2018-05-19
# 684       Private room    599               3                  7  2018-11-16
# 1451   Entire home/apt    595               5                 59  2019-06-27
# 1527   Entire home/apt    550               4                173  2019-07-01
# ...                ...    ...             ...                ...         ...
# 48119  Entire home/apt    583              30                  0         NaN
# 48170  Entire home/apt    550               4                  0         NaN
# 48184  Entire home/apt    595               2                  0         NaN
# 48232     Private room    561               1                  0         NaN
# 48740  Entire home/apt    550               3                  1  2019-07-07
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 299                 1.88                               1               298
# 365                 0.09                              28                60
# 684                 0.08                              28                60
# 1451                0.77                               1               169
# 1527                2.12                               1               258
# ...                  ...                             ...               ...
# 48119                NaN                               6               343
# 48170                NaN                               1                34
# 48184                NaN                               3               340
# 48232                NaN                               1               364
# 48740               1.00                               1               230
#
# [127 rows x 13 columns]
# 600 - 649
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 1621        Staten Island            Arrochar   600 - 649  40.****  -74.****
# 1679            Manhattan     Upper West Side   600 - 649  40.****  -73.****
# 2759            Manhattan         Murray Hill   600 - 649  40.****  -73.****
# 2857             Brooklyn  Bedford-Stuyvesant   600 - 649  40.****  -73.****
# 3135            Manhattan     Upper East Side   600 - 649  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 47664           Manhattan  Financial District   600 - 649  40.****  -74.****
# 47694           Manhattan     Upper East Side   600 - 649  40.****  -73.****
# 47754           Manhattan            Kips Bay   600 - 649  40.****  -73.****
# 48310               Bronx         City Island   600 - 649  40.****  -73.****
# 48378           Manhattan                SoHo   600 - 649  40.****  -74.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 1621   Entire home/apt    625               4                  1  2015-11-01
# 1679   Entire home/apt    600               3                  9  2018-10-20
# 2759   Entire home/apt    600               4                  7  2015-09-04
# 2857   Entire home/apt    600               1                 48  2015-10-11
# 3135   Entire home/apt    600               3                 46  2019-05-27
# ...                ...    ...             ...                ...         ...
# 47664  Entire home/apt    600               3                  0         NaN
# 47694  Entire home/apt    600               3                  0         NaN
# 47754  Entire home/apt    600               3                  0         NaN
# 48310  Entire home/apt    600               1                  0         NaN
# 48378  Entire home/apt    600               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1621                0.02                               4               335
# 1679                0.12                               2               353
# 2759                0.10                               1                 0
# 2857                0.68                               1                89
# 3135                0.67                               1               210
# ...                  ...                             ...               ...
# 47664                NaN                               1               355
# 47694                NaN                               1               357
# 47754                NaN                               1               355
# 48310                NaN                               4                44
# 48378                NaN                               1               179
#
# [104 rows x 13 columns]
# 650 - 699
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 345              Brooklyn        Clinton Hill   650 - 699  40.****  -73.****
# 2100            Manhattan                SoHo   650 - 699  40.****  -73.****
# 2296            Manhattan            Kips Bay   650 - 699  40.****  -73.****
# 3233             Brooklyn          Park Slope   650 - 699  40.****  -73.****
# 3644            Manhattan     Upper East Side   650 - 699  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 46931            Brooklyn            Bushwick   650 - 699  40.****  -73.****
# 47533           Manhattan            Kips Bay   650 - 699  40.****  -73.****
# 47814           Manhattan  Financial District   650 - 699  40.****  -74.****
# 47821           Manhattan  Financial District   650 - 699  40.****  -74.****
# 47995           Manhattan             Midtown   650 - 699  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 345    Entire home/apt    650               5                  0         NaN
# 2100   Entire home/apt    650               5                  7  2014-06-27
# 2296   Entire home/apt    650              30                 36  2019-06-29
# 3233   Entire home/apt    650               2                166  2019-06-24
# 3644   Entire home/apt    675               5                  3  2014-09-09
# ...                ...    ...             ...                ...         ...
# 46931  Entire home/apt    650               2                  1  2019-06-16
# 47533  Entire home/apt    650               1                  0         NaN
# 47814  Entire home/apt    699              29                  0         NaN
# 47821  Entire home/apt    699              29                  0         NaN
# 47995  Entire home/apt    650               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 345                  NaN                               3               365
# 2100                0.09                               2                90
# 2296                0.48                               1               256
# 3233                2.87                               1               215
# 3644                0.05                               1                 0
# ...                  ...                             ...               ...
# 46931               1.00                               3               338
# 47533                NaN                               9               302
# 47814                NaN                             327               327
# 47821                NaN                             327               341
# 47995                NaN                               1               337
#
# [119 rows x 13 columns]
# 700 - 749
#       neighbourhood_group   neighbourhood price_range latitude longitude  \
# 653             Manhattan    West Village   700 - 749  40.****  -74.****
# 1315            Manhattan          Harlem   700 - 749  40.****  -73.****
# 1426            Manhattan    West Village   700 - 749  40.****  -74.****
# 3049        Staten Island         Woodrow   700 - 749  40.****  -74.****
# 3478             Brooklyn    Williamsburg   700 - 749  40.****  -73.****
# ...                   ...             ...         ...      ...       ...
# 44647            Brooklyn      Greenpoint   700 - 749  40.****  -73.****
# 46003           Manhattan    East Village   700 - 749  40.****  -73.****
# 46432           Manhattan  Hell's Kitchen   700 - 749  40.****  -73.****
# 46630           Manhattan  Hell's Kitchen   700 - 749  40.****  -73.****
# 48757           Manhattan         Tribeca   700 - 749  40.****  -74.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 653    Entire home/apt    700               3                131  2019-06-24
# 1315      Private room    700              28                  4  2016-10-03
# 1426   Entire home/apt    700               5                  1  2012-09-18
# 3049   Entire home/apt    700               7                  0         NaN
# 3478   Entire home/apt    700               3                  1  2014-01-02
# ...                ...    ...             ...                ...         ...
# 44647  Entire home/apt    700              15                  0         NaN
# 46003  Entire home/apt    700               6                  0         NaN
# 46432  Entire home/apt    700               2                  0         NaN
# 46630  Entire home/apt    700               4                  2  2019-06-22
# 48757  Entire home/apt    700               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 653                 1.40                               4               296
# 1315                0.05                               1                22
# 1426                0.01                               1               365
# 3049                 NaN                               1                 0
# 3478                0.01                               1                 0
# ...                  ...                             ...               ...
# 44647                NaN                               1                24
# 46003                NaN                               1                 9
# 46432                NaN                               1               304
# 46630               2.00                               1               130
# 48757                NaN                               1                37
#
# [83 rows x 13 columns]
# 750 - 799
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 691             Manhattan             Chelsea   750 - 799  40.****  -74.****
# 2356            Manhattan        East Village   750 - 799  40.****  -73.****
# 3055            Manhattan             Midtown   750 - 799  40.****  -73.****
# 3240             Brooklyn        Clinton Hill   750 - 799  40.****  -73.****
# 3601            Manhattan     Upper West Side   750 - 799  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 47400           Manhattan  Washington Heights   750 - 799  40.****  -73.****
# 47616           Manhattan  Financial District   750 - 799  40.****  -74.****
# 47748           Manhattan        West Village   750 - 799  40.****  -74.****
# 48343           Manhattan             Chelsea   750 - 799  40.****  -73.****
# 48697           Manhattan     Upper West Side   750 - 799  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 691    Entire home/apt    760               2                  7  2019-06-22
# 2356   Entire home/apt    750               3                  9  2018-08-30
# 3055   Entire home/apt    799               6                 40  2018-09-01
# 3240   Entire home/apt    750               3                 32  2019-05-19
# 3601   Entire home/apt    750               3                  0         NaN
# ...                ...    ...             ...                ...         ...
# 47400  Entire home/apt    750               1                  1  2019-07-07
# 47616  Entire home/apt    750               3                  0         NaN
# 47748  Entire home/apt    750               1                  0         NaN
# 48343  Entire home/apt    750               1                  0         NaN
# 48697  Entire home/apt    750               4                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 691                 0.08                               1               361
# 2356                0.18                               2               364
# 3055                0.58                               1               365
# 3240                1.66                               1               141
# 3601                 NaN                               1                 0
# ...                  ...                             ...               ...
# 47400               1.00                               5               364
# 47616                NaN                               1               352
# 47748                NaN                               1                 5
# 48343                NaN                               1                89
# 48697                NaN                               1               174
#
# [79 rows x 13 columns]
# 800 - 849
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 85               Brooklyn    Brooklyn Heights   800 - 849  40.****  -73.****
# 780              Brooklyn  Bedford-Stuyvesant   800 - 849  40.****  -73.****
# 1201             Brooklyn    Brooklyn Heights   800 - 849  40.****  -73.****
# 1910             Brooklyn            Bushwick   800 - 849  40.****  -73.****
# 2618            Manhattan        West Village   800 - 849  40.****  -74.****
# ...                   ...                 ...         ...      ...       ...
# 47094           Manhattan             Midtown   800 - 849  40.****  -73.****
# 47206           Manhattan            Kips Bay   800 - 849  40.****  -73.****
# 47870            Brooklyn         Fort Greene   800 - 849  40.****  -73.****
# 47950           Manhattan             Chelsea   800 - 849  40.****  -74.****
# 48839            Brooklyn      Sheepshead Bay   800 - 849  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 85     Entire home/apt    800               1                 25  2016-08-04
# 780    Entire home/apt    800               4                122  2019-07-02
# 1201   Entire home/apt    800               3                 60  2019-01-01
# 1910   Entire home/apt    800               1                 34  2019-07-01
# 2618   Entire home/apt    800               1                  2  2014-08-23
# ...                ...    ...             ...                ...         ...
# 47094  Entire home/apt    800              30                  0         NaN
# 47206  Entire home/apt    800               2                  0         NaN
# 47870  Entire home/apt    800               3                  0         NaN
# 47950  Entire home/apt    800               3                  1  2019-07-01
# 48839     Private room    800               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 85                  0.24                               1                 7
# 780                 1.37                               1               257
# 1201                0.70                               1                67
# ...
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7250 - 7299
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7300 - 7349
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7350 - 7399
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7400 - 7449
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7450 - 7499
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7500 - 7549
#       neighbourhood_group      neighbourhood  price_range latitude longitude  \
# 42523           Manhattan  Battery Park City  7500 - 7549  40.****  -74.****
# 45666            Brooklyn      East Flatbush  7500 - 7549  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 42523  Entire home/apt   7500               1                  0         NaN
# 45666     Private room   7500               1                  8  2019-07-07
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 42523                NaN                               1               364
# 45666               6.15                               2               179
# 7550 - 7599
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7600 - 7649
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7650 - 7699
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7700 - 7749
#       neighbourhood_group    neighbourhood  price_range latitude longitude  \
# 29662           Manhattan  Upper East Side  7700 - 7749  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 29662  Entire home/apt   7703               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 29662                NaN                              12               146
# 7750 - 7799
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7800 - 7849
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7850 - 7899
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7900 - 7949
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 7950 - 7999
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8000 - 8049
#      neighbourhood_group neighbourhood  price_range latitude longitude  \
# 4377            Brooklyn  Clinton Hill  8000 - 8049  40.****  -73.****
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 4377  Entire home/apt   8000               1                  1  2016-09-15
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 4377               0.03                              11               365
# 8050 - 8099
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8100 - 8149
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8150 - 8199
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8200 - 8249
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8250 - 8299
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8300 - 8349
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8350 - 8399
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8400 - 8449
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8450 - 8499
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8500 - 8549
#       neighbourhood_group neighbourhood  price_range latitude longitude  \
# 30268           Manhattan       Tribeca  8500 - 8549  40.****  -74.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 30268  Entire home/apt   8500              30                  2  2018-09-18
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 30268               0.18                               1               251
# 8550 - 8599
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8600 - 8649
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8650 - 8699
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8700 - 8749
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8750 - 8799
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8800 - 8849
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8850 - 8899
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8900 - 8949
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 8950 - 8999
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9000 - 9049
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9050 - 9099
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9100 - 9149
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9150 - 9199
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9200 - 9249
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9250 - 9299
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9300 - 9349
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9350 - 9399
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9400 - 9449
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9450 - 9499
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9500 - 9549
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9550 - 9599
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9600 - 9649
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9650 - 9699
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9700 - 9749
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9750 - 9799
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9800 - 9849
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9850 - 9899
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9900 - 9949
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, price_range, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []
# 9950 - 9999
#       neighbourhood_group    neighbourhood  price_range latitude longitude  \
# 6530            Manhattan      East Harlem  9950 - 9999  40.****  -73.****
# 12342           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
# 40433           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 6530   Entire home/apt   9999               5                  1  2015-01-02
# 12342     Private room   9999              99                  6  2016-01-01
# 40433  Entire home/apt   9999              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365

# %%
#g.groups
#for value in g.groups.items():
 #   print(value)

# %% [markdown]
# <span style="font-size:1.5em;">Now we will group the data with respect to the price range, and also make sure that rows with empty price ranges do not get appended to the new dataframe. We will use an ordered dictionary to order the price table with respect to price range in ascending order. The dataframe that is '**GeneralDF**'.</span>

# %%
#we import ordered dictionary 
from collections import OrderedDict

myarr = OrderedDict()

# %%
#print(group_list)
for key, value in g.groups.items():
    indices = list(value)
    newdf = air_db.iloc[indices]
    if len(newdf) == 0:
        continue
    else:
        myarr[key] = newdf
#test    
myarr['100 - 149']
# Out:
#       neighbourhood_group    neighbourhood price_range latitude longitude  \
# 0                Brooklyn       Kensington   100 - 149  40.****  -73.****
# 10              Manhattan  Upper West Side   100 - 149  40.****  -73.****
# 14              Manhattan     West Village   100 - 149  40.****  -74.****
# 15               Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 17              Manhattan          Chelsea   100 - 149  40.****  -73.****
# ...                   ...              ...         ...      ...       ...
# 48875           Manhattan      East Harlem   100 - 149  40.****  -73.****
# 48879            Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 48880            Brooklyn     Williamsburg   100 - 149  40.****  -73.****
# 48888           Manhattan   Hell's Kitchen   100 - 149  40.****  -73.****
# 48892           Manhattan           Harlem   100 - 149  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 10     Entire home/apt    135               5                 53  2019-06-22
# 14     Entire home/apt    120              90                 27  2018-10-31
# 15     Entire home/apt    140               2                148  2019-06-29
# 17        Private room    140               1                260  2019-07-01
# ...                ...    ...             ...                ...         ...
# 48875     Private room    140               1                  0         NaN
# 48879  Entire home/apt    120              20                  0         NaN
# 48880  Entire home/apt    120               1                  0         NaN
# 48888     Private room    125               4                  0         NaN
# 48892  Entire home/apt    115              10                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 10                  0.43                               1                 6
# 14                  0.22                               1                 0
# 15                  1.20                               1                46
# 17                  2.12                               1                12
# ...                  ...                             ...               ...
# 48875                NaN                               1               180
# 48879                NaN                               1                22
# 48880                NaN                               3               365
# 48888                NaN                               1                31
# 48892                NaN                               1                27
#
# [10033 rows x 13 columns]

# %%
print(len(list(g.groups.keys())))

print(len(list(myarr.keys())))
# Out:
# 200
# 80

# %%
myarr.keys()

# %%
generalDF = pd.DataFrame(myarr['0 - 49'])
for key, value in myarr.items():
    if key != '0 - 49':
        tempdf = myarr[key]
        #print(key)
        generalDF = pd.concat([generalDF, tempdf])

# %%
generalDF
# Out:
#       neighbourhood_group       neighbourhood  price_range latitude longitude  \
# 28              Manhattan              Inwood       0 - 49  40.****  -73.****
# 36               Brooklyn  Bedford-Stuyvesant       0 - 49  40.****  -73.****
# 39              Manhattan     Lower East Side       0 - 49  40.****  -73.****
# 58               Brooklyn          Greenpoint       0 - 49  40.****  -73.****
# 149              Brooklyn         Fort Greene       0 - 49  40.****  -73.****
# ...                   ...                 ...          ...      ...       ...
# 4377             Brooklyn        Clinton Hill  8000 - 8049  40.****  -73.****
# 30268           Manhattan             Tribeca  8500 - 8549  40.****  -74.****
# 6530            Manhattan         East Harlem  9950 - 9999  40.****  -73.****
# 12342           Manhattan     Lower East Side  9950 - 9999  40.****  -73.****
# 40433           Manhattan     Lower East Side  9950 - 9999  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 28        Private room     44               3                108  2019-06-15
# 36        Private room     35              60                  0         NaN
# 39         Shared room     40               1                214  2019-07-05
# 58        Private room     49               4                138  2019-06-04
# 149       Private room     44               8                 27  2019-06-29
# ...                ...    ...             ...                ...         ...
# 4377   Entire home/apt   8000               1                  1  2016-09-15
# 30268  Entire home/apt   8500              30                  2  2018-09-18
# 6530   Entire home/apt   9999               5                  1  2015-01-02
# 12342     Private room   9999              99                  6  2016-01-01
# 40433  Entire home/apt   9999              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 28                  1.11                               3               311
# 36                   NaN                               1               365
# 39                  1.81                               4               188
# 58                  1.19                               3               320
# 149                 1.05                               5               280
# ...                  ...                             ...               ...
# 4377                0.03                              11               365
# 30268               0.18                               1               251
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365
#
# [48892 rows x 13 columns]

# %%
# Interquartile range to understand the distribution of price
Q1 = generalDF['price'].quantile(0.25)
Q3 = generalDF['price'].quantile(0.75)
IQR = Q3 - Q1
print(Q1)
print(Q3)
print(IQR)
# Out:
# 69.0
# 175.0
# 106.0

# %% [markdown]
# <span style="font-size:1.5em;">
# Observing the data frame above we can clearly see that there are only
# three properities in the '9950 - 9999' price range, which is definitely not good for anonymization.
# We can also notice from the functions above that most of the price data in this table is below $1000. Hence we will
# split the generalDF into two dataframes:
#
# * subsetdataframe1(for price < 1000 dollars)
# * subsetdataframe2(for price > 999 dollars)
#
# </span>

# %%
#using the key array we split the Dataframe for price < 1000
subsetdataframe1 = generalDF[generalDF['price_range'].isin(['0 - 49', '50 - 99', '100 - 149', '150 - 199', '200 - 249', '250 - 299', '300 - 349', '350 - 399', '400 - 449', '450 - 499', '500 - 549', '550 - 599', '600 - 649', '650 - 699', '700 - 749', '750 - 799', '800 - 849', '850 - 899', '900 - 949', '950 - 999'])]
subsetdataframe1
# Out:
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 28              Manhattan              Inwood      0 - 49  40.****  -73.****
# 36               Brooklyn  Bedford-Stuyvesant      0 - 49  40.****  -73.****
# 39              Manhattan     Lower East Side      0 - 49  40.****  -73.****
# 58               Brooklyn          Greenpoint      0 - 49  40.****  -73.****
# 149              Brooklyn         Fort Greene      0 - 49  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 46291           Manhattan        West Village   950 - 999  40.****  -74.****
# 46438           Manhattan   Flatiron District   950 - 999  40.****  -73.****
# 46596           Manhattan        West Village   950 - 999  40.****  -74.****
# 46965           Manhattan        Civic Center   950 - 999  40.****  -74.****
# 48301           Manhattan             Chelsea   950 - 999  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 28        Private room     44               3                108  2019-06-15
# 36        Private room     35              60                  0         NaN
# 39         Shared room     40               1                214  2019-07-05
# 58        Private room     49               4                138  2019-06-04
# 149       Private room     44               8                 27  2019-06-29
# ...                ...    ...             ...                ...         ...
# 46291  Entire home/apt    995               1                  3  2019-07-05
# 46438  Entire home/apt    950               1                  0         NaN
# 46596     Private room    999               1                  2  2019-07-05
# 46965  Entire home/apt    950               3                  0         NaN
# 48301     Private room    999              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 28                  1.11                               3               311
# 36                   NaN                               1               365
# 39                  1.81                               4               188
# 58                  1.19                               3               320
# 149                 1.05                               5               280
# ...                  ...                             ...               ...
# 46291               3.00                               1               344
# 46438                NaN                               1               365
# 46596               2.00                               5               321
# 46965                NaN                               1                69
# 48301                NaN                               1               270
#
# [48597 rows x 13 columns]

# %%
#using the key array we split the Dataframe for price > 999
subsetdataframe2 = generalDF[generalDF['price_range'].isin(['1000 - 1049', '1050 - 1099', '1100 - 1149', '1150 - 1199', '1200 - 1249', '1250 - 1299', '1300 - 1349', '1350 - 1399', '1400 - 1449', '1450 - 1499', '1500 - 1549', '1550 - 1599', '1600 - 1649', '1650 - 1699', '1700 - 1749', '1750 - 1799', '1800 - 1849', '1850 - 1899', '1900 - 1949', '1950 - 1999', '2000 - 2049', '2100 - 2149', '2200 - 2249', '2250 - 2299', '2300 - 2349', '2350 - 2399', '2400 - 2449', '2500 - 2549', '2550 - 2599', '2600 - 2649', '2650 - 2699', '2750 - 2799', '2800 - 2849', '2850 - 2899', '2900 - 2949', '2950 - 2999', '3000 - 3049', '3200 - 3249', '3500 - 3549', '3600 - 3649', '3750 - 3799', '3800 - 3849', '3900 - 3949', '4000 - 4049', '4100 - 4149', '4150 - 4199', '4200 - 4249', '4500 - 4549', '5000 - 5049', '5100 - 5149', '5250 - 5299', '6000 - 6049', '6400 - 6449', '6500 - 6549', '6800 - 6849', '7500 - 7549', '7700 - 7749', '8000 - 8049', '8500 - 8549', '9950 - 9999'])]
subsetdataframe2
# Out:
#       neighbourhood_group    neighbourhood  price_range latitude longitude  \
# 1414            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# 2215            Manhattan          Tribeca  1000 - 1049  40.****  -74.****
# 2355            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# 2386            Manhattan   Hell's Kitchen  1000 - 1049  40.****  -73.****
# 3345            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# ...                   ...              ...          ...      ...       ...
# 4377             Brooklyn     Clinton Hill  8000 - 8049  40.****  -73.****
# 30268           Manhattan          Tribeca  8500 - 8549  40.****  -74.****
# 6530            Manhattan      East Harlem  9950 - 9999  40.****  -73.****
# 12342           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
# 40433           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 1414   Entire home/apt   1000              30                 44  2015-09-28
# 2215   Entire home/apt   1000               1                 25  2019-06-22
# 2355   Entire home/apt   1000              30                 24  2016-01-27
# 2386   Entire home/apt   1000               1                  0         NaN
# 3345   Entire home/apt   1000               1                  0         NaN
# ...                ...    ...             ...                ...         ...
# 4377   Entire home/apt   8000               1                  1  2016-09-15
# 30268  Entire home/apt   8500              30                  2  2018-09-18
# 6530   Entire home/apt   9999               5                  1  2015-01-02
# 12342     Private room   9999              99                  6  2016-01-01
# 40433  Entire home/apt   9999              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1414                0.53                              11               364
# 2215                0.36                               3                37
# 2355                0.33                              11               364
# 2386                 NaN                               1               365
# 3345                 NaN                               1                 0
# ...                  ...                             ...               ...
# 4377                0.03                              11               365
# 30268               0.18                               1               251
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365
#
# [295 rows x 13 columns]

# %% [markdown]
# <span style="font-size:1.5em;"> For subsetdataframe2 we want to replace all the values in price_range and change it to ">=100". This is slightly tricky as the ".mask" function I used before only works on int64 data types which price_range is not. So instead of doing this operation on price_range, I did the operation on the price field (remember I did not remove price from the tables yet). I then dropped price_range from the table and inserted a copy of the modified 'price' column into the same position as price_range with the same name.</span>

# %%
pd.set_option('mode.chained_assignment', None)
price=subsetdataframe2['price']
subsetdataframe2['price'] = subsetdataframe2['price'].mask(price > 999, ">=1000")

# %%
subsetdataframe2
# Out:
#       neighbourhood_group    neighbourhood  price_range latitude longitude  \
# 1414            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# 2215            Manhattan          Tribeca  1000 - 1049  40.****  -74.****
# 2355            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# 2386            Manhattan   Hell's Kitchen  1000 - 1049  40.****  -73.****
# 3345            Manhattan  Upper West Side  1000 - 1049  40.****  -73.****
# ...                   ...              ...          ...      ...       ...
# 4377             Brooklyn     Clinton Hill  8000 - 8049  40.****  -73.****
# 30268           Manhattan          Tribeca  8500 - 8549  40.****  -74.****
# 6530            Manhattan      East Harlem  9950 - 9999  40.****  -73.****
# 12342           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
# 40433           Manhattan  Lower East Side  9950 - 9999  40.****  -73.****
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 1414   Entire home/apt  >=1000              30                 44  2015-09-28
# 2215   Entire home/apt  >=1000               1                 25  2019-06-22
# 2355   Entire home/apt  >=1000              30                 24  2016-01-27
# 2386   Entire home/apt  >=1000               1                  0         NaN
# 3345   Entire home/apt  >=1000               1                  0         NaN
# ...                ...     ...             ...                ...         ...
# 4377   Entire home/apt  >=1000               1                  1  2016-09-15
# 30268  Entire home/apt  >=1000              30                  2  2018-09-18
# 6530   Entire home/apt  >=1000               5                  1  2015-01-02
# 12342     Private room  >=1000              99                  6  2016-01-01
# 40433  Entire home/apt  >=1000              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1414                0.53                              11               364
# 2215                0.36                               3                37
# 2355                0.33                              11               364
# 2386                 NaN                               1               365
# 3345                 NaN                               1                 0
# ...                  ...                             ...               ...
# 4377                0.03                              11               365
# 30268               0.18                               1               251
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365
#
# [295 rows x 13 columns]

# %%
subsetdataframe2 = subsetdataframe2.drop("price_range", axis=1)
subsetdataframe2
# Out:
#       neighbourhood_group    neighbourhood latitude longitude  \
# 1414            Manhattan  Upper West Side  40.****  -73.****
# 2215            Manhattan          Tribeca  40.****  -74.****
# 2355            Manhattan  Upper West Side  40.****  -73.****
# 2386            Manhattan   Hell's Kitchen  40.****  -73.****
# 3345            Manhattan  Upper West Side  40.****  -73.****
# ...                   ...              ...      ...       ...
# 4377             Brooklyn     Clinton Hill  40.****  -73.****
# 30268           Manhattan          Tribeca  40.****  -74.****
# 6530            Manhattan      East Harlem  40.****  -73.****
# 12342           Manhattan  Lower East Side  40.****  -73.****
# 40433           Manhattan  Lower East Side  40.****  -73.****
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 1414   Entire home/apt  >=1000              30                 44  2015-09-28
# 2215   Entire home/apt  >=1000               1                 25  2019-06-22
# 2355   Entire home/apt  >=1000              30                 24  2016-01-27
# 2386   Entire home/apt  >=1000               1                  0         NaN
# 3345   Entire home/apt  >=1000               1                  0         NaN
# ...                ...     ...             ...                ...         ...
# 4377   Entire home/apt  >=1000               1                  1  2016-09-15
# 30268  Entire home/apt  >=1000              30                  2  2018-09-18
# 6530   Entire home/apt  >=1000               5                  1  2015-01-02
# 12342     Private room  >=1000              99                  6  2016-01-01
# 40433  Entire home/apt  >=1000              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1414                0.53                              11               364
# 2215                0.36                               3                37
# 2355                0.33                              11               364
# 2386                 NaN                               1               365
# 3345                 NaN                               1                 0
# ...                  ...                             ...               ...
# 4377                0.03                              11               365
# 30268               0.18                               1               251
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365
#
# [295 rows x 12 columns]

# %%
price_range_2 =subsetdataframe2['price']

subsetdataframe2.insert(2, "price_range",price_range_2)
subsetdataframe2.head()
# Out:
#      neighbourhood_group    neighbourhood price_range latitude longitude  \
# 1414           Manhattan  Upper West Side      >=1000  40.****  -73.****
# 2215           Manhattan          Tribeca      >=1000  40.****  -74.****
# 2355           Manhattan  Upper West Side      >=1000  40.****  -73.****
# 2386           Manhattan   Hell's Kitchen      >=1000  40.****  -73.****
# 3345           Manhattan  Upper West Side      >=1000  40.****  -73.****
#
#             room_type   price  minimum_nights  number_of_reviews last_review  \
# 1414  Entire home/apt  >=1000              30                 44  2015-09-28
# 2215  Entire home/apt  >=1000               1                 25  2019-06-22
# 2355  Entire home/apt  >=1000              30                 24  2016-01-27
# 2386  Entire home/apt  >=1000               1                  0         NaN
# 3345  Entire home/apt  >=1000               1                  0         NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 1414               0.53                              11               364
# 2215               0.36                               3                37
# 2355               0.33                              11               364
# 2386                NaN                               1               365
# 3345                NaN                               1                 0

# %% [markdown]
# <span style="font-size:1.5em;">Now we will drop price from both subset dataframes and join them together to get the nearly anonymized dataset.  </span>

# %%
subsetdataframe1 = subsetdataframe1.drop("price", axis=1)
subsetdataframe2 = subsetdataframe2.drop("price", axis=1)

# %%
nearly_anon_db = pd.concat([subsetdataframe1,subsetdataframe2])
nearly_anon_db
# Out:
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 28              Manhattan              Inwood      0 - 49  40.****  -73.****
# 36               Brooklyn  Bedford-Stuyvesant      0 - 49  40.****  -73.****
# 39              Manhattan     Lower East Side      0 - 49  40.****  -73.****
# 58               Brooklyn          Greenpoint      0 - 49  40.****  -73.****
# 149              Brooklyn         Fort Greene      0 - 49  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 4377             Brooklyn        Clinton Hill      >=1000  40.****  -73.****
# 30268           Manhattan             Tribeca      >=1000  40.****  -74.****
# 6530            Manhattan         East Harlem      >=1000  40.****  -73.****
# 12342           Manhattan     Lower East Side      >=1000  40.****  -73.****
# 40433           Manhattan     Lower East Side      >=1000  40.****  -73.****
#
#              room_type  minimum_nights  number_of_reviews last_review  \
# 28        Private room               3                108  2019-06-15
# 36        Private room              60                  0         NaN
# 39         Shared room               1                214  2019-07-05
# 58        Private room               4                138  2019-06-04
# 149       Private room               8                 27  2019-06-29
# ...                ...             ...                ...         ...
# 4377   Entire home/apt               1                  1  2016-09-15
# 30268  Entire home/apt              30                  2  2018-09-18
# 6530   Entire home/apt               5                  1  2015-01-02
# 12342     Private room              99                  6  2016-01-01
# 40433  Entire home/apt              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 28                  1.11                               3               311
# 36                   NaN                               1               365
# 39                  1.81                               4               188
# 58                  1.19                               3               320
# 149                 1.05                               5               280
# ...                  ...                             ...               ...
# 4377                0.03                              11               365
# 30268               0.18                               1               251
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
# 40433                NaN                               1               365
#
# [48892 rows x 12 columns]

# %% [markdown]
# <span style="font-size:1.5em;"> For the sensitive column **calculated_host_listings_count**, we will mask all the rows as it can be used to identify individuals. This is will the last step, and we will have a k-anonymized dataset grouped by price range.  </span>

# %%
calculated_host_listings_count = nearly_anon_db['calculated_host_listings_count']
nearly_anon_db['calculated_host_listings_count'] = nearly_anon_db['calculated_host_listings_count'].mask(calculated_host_listings_count>-1,"***")

# %%
K_Anon_DB = nearly_anon_db
K_Anon_DB
# Out:
#       neighbourhood_group       neighbourhood price_range latitude longitude  \
# 28              Manhattan              Inwood      0 - 49  40.****  -73.****
# 36               Brooklyn  Bedford-Stuyvesant      0 - 49  40.****  -73.****
# 39              Manhattan     Lower East Side      0 - 49  40.****  -73.****
# 58               Brooklyn          Greenpoint      0 - 49  40.****  -73.****
# 149              Brooklyn         Fort Greene      0 - 49  40.****  -73.****
# ...                   ...                 ...         ...      ...       ...
# 4377             Brooklyn        Clinton Hill      >=1000  40.****  -73.****
# 30268           Manhattan             Tribeca      >=1000  40.****  -74.****
# 6530            Manhattan         East Harlem      >=1000  40.****  -73.****
# 12342           Manhattan     Lower East Side      >=1000  40.****  -73.****
# 40433           Manhattan     Lower East Side      >=1000  40.****  -73.****
#
#              room_type  minimum_nights  number_of_reviews last_review  \
# 28        Private room               3                108  2019-06-15
# 36        Private room              60                  0         NaN
# 39         Shared room               1                214  2019-07-05
# 58        Private room               4                138  2019-06-04
# 149       Private room               8                 27  2019-06-29
# ...                ...             ...                ...         ...
# 4377   Entire home/apt               1                  1  2016-09-15
# 30268  Entire home/apt              30                  2  2018-09-18
# 6530   Entire home/apt               5                  1  2015-01-02
# 12342     Private room              99                  6  2016-01-01
# 40433  Entire home/apt              30                  0         NaN
#
#        reviews_per_month calculated_host_listings_count  availability_365
# 28                  1.11                            ***               311
# 36                   NaN                            ***               365
# 39                  1.81                            ***               188
# 58                  1.19                            ***               320
# 149                 1.05                            ***               280
# ...                  ...                            ...               ...
# 4377                0.03                            ***               365
# 30268               0.18                            ***               251
# 6530                0.02                            ***                 0
# 12342               0.14                            ***                83
# 40433                NaN                            ***               365
#
# [48892 rows x 12 columns]

# %% [markdown]
# <span style="font-size:1.5em;"> Finally, we will exported the anonymized dataframe to a '.csv' file. </span>

# %%
K_Anon_DB.to_csv("/Users/arko/Desktop/K_Anon_DB.csv")
